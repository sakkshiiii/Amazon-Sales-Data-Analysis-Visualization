# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Amazon Sale Report.csv')

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head(1)
# Out:
#        index             Order ID      Date                        Status  \
# 49051  49051  408-4858463-2356347  05-31-22  Shipped - Delivered to Buyer
#
#       Fulfilment Sales Channel  ship-service-level  Style         SKU  \
# 49051   Merchant      Amazon.in           Standard  J0385  J0385-KR-M
#
#       Category  ... currency Amount    ship-city      ship-state  \
# 49051    kurta  ...      INR  888.0  RAJAHMUNDRY  ANDHRA PRADESH
#
#       ship-postal-code  ship-country  \
# 49051         533126.0            IN
#
#                                            promotion-ids    B2B  fulfilled-by  \
# 49051  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
#
#       Unnamed: 22
# 49051       False
#
# [1 rows x 24 columns]

# %%
df[::1]
# Out:
#          index             Order ID      Date                        Status  \
# 49051    49051  408-4858463-2356347  05-31-22  Shipped - Delivered to Buyer
# 49077    49077  402-7697834-2682766  05-31-22  Shipped - Delivered to Buyer
# 49081    49081  402-7031777-0396341  05-31-22  Shipped - Delivered to Buyer
# 49082    49082  408-1235521-4337163  05-31-22  Shipped - Delivered to Buyer
# 49083    49083  403-3845187-4421165  05-31-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 128872  128872  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128873  128873  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128874  128874  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128887  128887  405-6493630-8542756  05-31-22  Shipped - Delivered to Buyer
# 128891  128891  403-0317423-9322704  05-31-22  Shipped - Delivered to Buyer
#
# ...

# %%
age_sales = df.groupby('Category')['Amount'].sum()
age_sales.plot(kind='bar',title='Amount by Category', color='orange')
plt.xlabel("Amount")
plt.show()

# %%
df['fulfilled-by'].fillna("Easy Ship", inplace=True)

# %%
df.drop(['Sales Channel ', 'Unnamed: 22'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
df['Weekday'] = df['Date'].dt.day_name()

# %%
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.drop(['ship-country', 'B2B'], axis=1, inplace=True)

# %%
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# %%
# Monthly Sales Trend
monthly_sales = df.groupby(['Year', 'Month'])['Amount'].sum().reset_index()
monthly_sales['Month_Year'] = monthly_sales['Year'].astype(str) + '-' + monthly_sales['Month'].astype(str).str.zfill(2)

# %%
plt.figure(figsize=(14, 5))
sns.lineplot(data=monthly_sales, x='Month_Year', y='Amount', marker='o')
plt.title('📈 Monthly Sales Trend')
plt.xlabel('Month-Year')
plt.ylabel('Total Sales Amount')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#  Average Order Value Per Month
avg_order_value = df.groupby(['Year', 'Month'])['Amount'].mean().reset_index()
avg_order_value['Month_Year'] = avg_order_value['Year'].astype(str) + '-' + avg_order_value['Month'].astype(str).str.zfill(2)

# %%
#  Orders by Weekday
orders_by_weekday = df['Weekday'].value_counts().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# %%
# Plot: Orders by Weekday
plt.figure(figsize=(10, 5))
sns.barplot(x=orders_by_weekday.index, y=orders_by_weekday.values, palette="cubehelix")
plt.title("📅 Number of Orders by Weekday")
plt.xlabel("Weekday")
plt.ylabel("Number of Orders")
plt.tight_layout()
plt.show()

# %%
# Top-Selling Categories
top_products = df.groupby('Category')['Amount'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_products.values, y=top_products.index, palette="viridis")
plt.title("🏆 Top-Selling Categories by Revenue")
plt.xlabel("Revenue")
plt.ylabel("Product Category")
plt.tight_layout()
plt.show()

# %%
# Top States by Revenue
state_sales = df.groupby('ship-state')['Amount'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=state_sales.values, y=state_sales.index, palette="magma")
plt.title("🗺️ Revenue by Top 10 States")
plt.xlabel("Revenue")
plt.ylabel("State")
plt.tight_layout()
plt.show()

# %%
# Order Status Pie Chart
status_counts = df['Status'].value_counts()
plt.figure(figsize=(8, 5))
status_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("📦 Order Status Distribution")
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
status_summary = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percentage': (status_counts.values / total * 100).round(2)
})

# Display the table
print("📋 Order Status Summary:")
print(status_summary)
# Out:
# 📋 Order Status Summary:
#                           Status  Count  Percentage
# 0   Shipped - Delivered to Buyer  16672       86.03
# 1   Shipped - Returned to Seller   1054        5.44
# 2            Shipped - Picked Up    967        4.99
# 3  Pending - Waiting for Pick Up    280        1.44
# 4                        Pending    220        1.14
# 5  Shipped - Returning to Seller    143        0.74
# 6     Shipped - Out for Delivery     34        0.18
# 7    Shipped - Rejected by Buyer      5        0.03
# 8      Shipped - Lost in Transit      3        0.02
# 9              Shipped - Damaged      1        0.01
